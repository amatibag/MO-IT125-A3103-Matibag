# %%
# import panda
import pandas as pd

# %%
# read Customer Transaction.csv file
df = pd.read_csv(r"C:\Users\amatibag\OneDrive - Genesys Telecommunications Laboratories, Inc\MMDC\Second Year_1st Term\Math for ML Linear Algebra\Data Files\Customer Transaction.csv")
df
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3195  59f8afe5-173b-4e52-b641-f98183f1a891
# 3196  16d0b561-279d-4da9-9aa8-8c5906dff79a
# 3197  34e3f558-622e-4d6b-8d5d-07ab632e1b95
# 3198  d83178cf-653d-435c-a7e8-880361dec6e7
# 3199  d64b0c8d-1831-4b29-baa2-08c4d5c3a0f9
#
#                              TransactionID TransactionDate  Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.64
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.14
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.99
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.44
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.52
# ...                                    ...             ...     ...
# 3195  3121df10-58e5-4ed4-a05c-b1f12df6bcc7      2023-01-18  892.44
# 3196  dff4f636-2c55-4237-8c55-efb15b05949b      2024-02-13  431.64
# 3197  db0a4640-ea96-4fcd-989b-b71ba767529c      2022-12-26     NaN
# 3198  89a1c0bc-4d49-4913-bb0f-26bd56b46a34      2022-09-26  343.46
# 3199  6c47f481-3a5c-49bc-ab1d-2b198394b2e8      2023-06-20     NaN
#
#       ProductCategory  PaymentMethod
# 0            Clothing         PayPal
# 1     Health & Beauty  Bank Transfer
# 2            Clothing     Debit Card
# 3          Automotive         PayPal
# 4       Home & Garden  Bank Transfer
# ...               ...            ...
# 3195    Home & Garden  Bank Transfer
# 3196  Health & Beauty    Credit Card
# 3197    Home & Garden         PayPal
# 3198  Health & Beauty     Debit Card
# 3199      Electronics     Debit Card
#
# [3200 rows x 6 columns]

# %% [markdown]
# ## a. Check for duplicate rows and remove them

# %%
df = df.drop_duplicates()
df
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate  Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.64
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.14
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.99
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.44
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.52
# ...                                    ...             ...     ...
# 3153  652636b6-5c72-44e1-aefb-6adce412ee75      2023-12-05  974.25
# 3157  eb26a4f4-5af2-4e25-b1f2-fd0de5583f7b      10/08/2022   50.07
# 3164  7fbe5cc4-a35e-4e8e-89d7-7b439659b9f6      20/07/2022  272.68
# 3174  185ee140-348a-4461-bd40-07a7e8535815      2023-10-09       0
# 3177  c751a808-ed8d-44d0-8c52-8253ad564c9a      2023-09-22    -100
#
#       ProductCategory  PaymentMethod
# 0            Clothing         PayPal
# 1     Health & Beauty  Bank Transfer
# 2            Clothing     Debit Card
# 3          Automotive         PayPal
# 4       Home & Garden  Bank Transfer
# ...               ...            ...
# 3153      Electronics     Debit Card
# 3157       Automotive  Bank Transfer
# 3164         Clothing     Debit Card
# 3174  Health & Beauty         PayPal
# 3177  Health & Beauty    Credit Card
#
# [3015 rows x 6 columns]

# %% [markdown]
# ## b. Identify columns with missing values and decide how to handle them.

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# TransactionID        0
# TransactionDate      0
# Amount             283
# ProductCategory    282
# PaymentMethod        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 565

# %%
# Create df2 from df
df2 = df.copy()

# Replace null values in Amount with the mean and convert to int
df2['Amount'] = pd.to_numeric(df2['Amount'], errors='coerce')  # Convert to numeric, forcing errors to NaN
mean_amount = df2['Amount'].mean()
df2['Amount'] = df2['Amount'].fillna(mean_amount).astype(int)  # Fill NaN and convert to int

# Replace null values in ProductCategory with 'Others'
df2['ProductCategory'] = df2['ProductCategory'].fillna('Others')

# %%
df2.isnull().sum()
# Out:
# CustomerID         0
# TransactionID      0
# TransactionDate    0
# Amount             0
# ProductCategory    0
# PaymentMethod      0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df2
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate  Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15     117
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26     466
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23     563
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15     254
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03     590
# ...                                    ...             ...     ...
# 3153  652636b6-5c72-44e1-aefb-6adce412ee75      2023-12-05     974
# 3157  eb26a4f4-5af2-4e25-b1f2-fd0de5583f7b      10/08/2022      50
# 3164  7fbe5cc4-a35e-4e8e-89d7-7b439659b9f6      20/07/2022     272
# 3174  185ee140-348a-4461-bd40-07a7e8535815      2023-10-09       0
# 3177  c751a808-ed8d-44d0-8c52-8253ad564c9a      2023-09-22    -100
#
#       ProductCategory  PaymentMethod
# 0            Clothing         PayPal
# 1     Health & Beauty  Bank Transfer
# 2            Clothing     Debit Card
# 3          Automotive         PayPal
# 4       Home & Garden  Bank Transfer
# ...               ...            ...
# 3153      Electronics     Debit Card
# 3157       Automotive  Bank Transfer
# 3164         Clothing     Debit Card
# 3174  Health & Beauty         PayPal
# 3177  Health & Beauty    Credit Card
#
# [3015 rows x 6 columns]

# %% [markdown]
# ## c. Ensure columns have the appropriate data types.

# %%
print(df2.dtypes)
# Out:
# CustomerID         object
# TransactionID      object
# TransactionDate    object
# Amount              int32
# ProductCategory    object
# PaymentMethod      object
# dtype: object

# %%
# Convert SignupDate to datetime format
df2['TransactionDate'] = pd.to_datetime(df2['TransactionDate'], errors='coerce')

# %%
df2.isnull().sum()
# Out:
# CustomerID          0
# TransactionID       0
# TransactionDate    98
# Amount              0
# ProductCategory     0
# PaymentMethod       0
# dtype: int64

# %%
# unable to find a way to fix the 98 rows that has different format. Decided to drop the data instead

df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# CustomerID         0
# TransactionID      0
# TransactionDate    0
# Amount             0
# ProductCategory    0
# PaymentMethod      0
# dtype: int64

# %%
print(df2.dtypes)
# Out:
# CustomerID                 object
# TransactionID              object
# TransactionDate    datetime64[ns]
# Amount                      int32
# ProductCategory            object
# PaymentMethod              object
# dtype: object

# %%
df2
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3113  f05ec030-ac96-417d-a73c-e3ca3adc1a30
# 3123  8de3d5b9-1f1a-4bd7-b242-6cb09d7f3609
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate  Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15     117
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26     466
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23     563
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15     254
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03     590
# ...                                    ...             ...     ...
# 3113  f39c8b1d-595a-4656-8108-25981bf3fa14      2024-03-05     252
# 3123  5fca256b-cd5a-48fa-8b07-37f39adde8c9      2023-05-17    -100
# 3153  652636b6-5c72-44e1-aefb-6adce412ee75      2023-12-05     974
# 3174  185ee140-348a-4461-bd40-07a7e8535815      2023-10-09       0
# 3177  c751a808-ed8d-44d0-8c52-8253ad564c9a      2023-09-22    -100
#
#       ProductCategory  PaymentMethod
# 0            Clothing         PayPal
# 1     Health & Beauty  Bank Transfer
# 2            Clothing     Debit Card
# 3          Automotive         PayPal
# 4       Home & Garden  Bank Transfer
# ...               ...            ...
# 3113      Electronics     Debit Card
# 3123         Clothing  Bank Transfer
# 3153      Electronics     Debit Card
# 3174  Health & Beauty         PayPal
# 3177  Health & Beauty    Credit Card
#
# [2917 rows x 6 columns]
