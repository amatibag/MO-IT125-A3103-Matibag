# %%
# import panda
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read Social Media Interactions.csv file
df = pd.read_csv(r"C:\Users\amatibag\OneDrive - Genesys Telecommunications Laboratories, Inc\MMDC\Second Year_1st Term\Math for ML Linear Algebra\Data Files\Social Media Interactions.csv")
df
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3195  8d8fe8bd-2009-4a15-be37-83dba3cef447
# 3196  1756838b-8368-4852-b4a5-32a23643a3dd
# 3197  eb8bb3ce-e182-4a9c-8084-c55c738815e1
# 3198  a5d08a95-9dba-4e3d-b997-1cfdde6a89ef
# 3199  f8146100-569d-4cda-9d64-88c6ad98de5f
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11        NaN
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %% [markdown]
# ## a. Check for duplicate rows and remove them

# %%
## check null values per column
df.isnull().sum()
# Out:
# CustomerID           0
# InteractionID        0
# InteractionDate      0
# Platform           311
# InteractionType      0
# Sentiment          329
# dtype: int64

# %%
## check total null values
df.isnull().sum().sum()
# Out:
# 640

# %%
df = df.drop_duplicates()
df
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11        NaN
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %% [markdown]
# ## b. Identify columns with missing values and decide how to handle them.

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# InteractionID        0
# InteractionDate      0
# Platform           291
# InteractionType      0
# Sentiment          309
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 600

# %%
# Create df2 from df
df2 = df.copy()

# Replace null values in Platform with 'Others'
df2['Platform'] = df2['Platform'].fillna('Others')

# Replace null values in Sentiment with 'Neutral'
df2['Sentiment'] = df2['Sentiment'].fillna('Neutral')

# %%
df2.isnull().sum()
# Out:
# CustomerID         0
# InteractionID      0
# InteractionDate    0
# Platform           0
# InteractionType    0
# Sentiment          0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df2
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11     Others
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %% [markdown]
# ## c. Ensure columns have the appropriate data types.

# %%
print(df2.dtypes)
# Out:
# CustomerID         object
# InteractionID      object
# InteractionDate    object
# Platform           object
# InteractionType    object
# Sentiment          object
# dtype: object

# %%
# Convert SignupDate to datetime format
df2['InteractionDate'] = pd.to_datetime(df2['InteractionDate'], errors='coerce')

# %%
df2.isnull().sum()
# Out:
# CustomerID           0
# InteractionID        0
# InteractionDate    100
# Platform             0
# InteractionType      0
# Sentiment            0
# dtype: int64

# %%
# unable to find a way to fix the 100 rows that has different format. Decided to drop the data instead

df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# CustomerID         0
# InteractionID      0
# InteractionDate    0
# Platform           0
# InteractionType    0
# Sentiment          0
# dtype: int64

# %%
print(df2.dtypes)
# Out:
# CustomerID                 object
# InteractionID              object
# InteractionDate    datetime64[ns]
# Platform                   object
# InteractionType            object
# Sentiment                  object
# dtype: object

# %%
df2
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11     Others
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df3 = df2.copy()

# add month column
df3['Month'] = df2['InteractionDate'].dt.month_name()

# add year column
df3['Year'] = df2['InteractionDate'].dt.year

# %%
df3
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11     Others
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2920 entries, 0 to 3194
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2920 non-null   object
#  1   InteractionID    2920 non-null   object
#  2   InteractionDate  2920 non-null   datetime64[ns]
#  3   Platform         2920 non-null   object
#  4   InteractionType  2920 non-null   object
#  5   Sentiment        2920 non-null   object
#  6   Month            2920 non-null   object
#  7   Year             2920 non-null   int32
# dtypes: datetime64[ns](1), int32(1), object(6)
# memory usage: 193.9+ KB

# %%
df3.describe()
# Out:
#                      InteractionDate         Year
# count                           2920  2920.000000
# mean   2023-12-30 17:19:04.109588736  2023.498973
# min              2023-07-01 00:00:00  2023.000000
# 25%              2023-10-01 18:00:00  2023.000000
# 50%              2023-12-31 00:00:00  2023.000000
# 75%              2024-04-01 00:00:00  2024.000000
# max              2024-06-30 00:00:00  2024.000000
# std                              NaN     0.500085

# %%
df3.nunique()
# Out:
# CustomerID         1862
# InteractionID      2911
# InteractionDate     366
# Platform              4
# InteractionType       3
# Sentiment             5
# Month                12
# Year                  2
# dtype: int64

# %%
df3.sort_values(by="InteractionDate")
# Out:
#                                 CustomerID  \
# 2239  662e1733-738d-41ef-8538-645f35333eb3
# 2344  f9aed600-08f5-4583-b6d8-5ab32daaa213
# 1389  75675707-f167-4964-ae1c-9081f3a8f775
# 2151  76c1d696-0f1c-44b5-b749-8859545658eb
# 602   992bfbf0-9fcc-4fad-9efc-767f55dd26ae
# ...                                    ...
# 2672  5711d1af-71f2-4b99-a965-3ffdc39d32c8
# 2591  a6cdffb1-b3cf-4aa3-af54-e42be3a8c260
# 1203  c6890a2f-4535-4b1c-84ac-547f9612813f
# 2193  b29ddf39-3a1e-4a11-97fd-a2ec8ccf01c5
# 396   9eee2b1c-ef39-41e8-b34f-6be7cb9d05a6
#
#                              InteractionID InteractionDate   Platform  \
# 2239  9a22949f-3e01-40de-b9e9-68e57649cfe3      2023-07-01   Facebook
# 2344  dc68ea28-4ec2-456e-9af7-4dd76b372f32      2023-07-01     Others
# 1389  d6678c87-d69d-4773-bf31-a0a9c635f3d0      2023-07-01  Instagram
# 2151  3ab03c80-fdaa-4dda-b769-4e8065ff1fff      2023-07-01   Facebook
# 602   6d7d2b58-fbe2-457b-b259-642be4f0b31c      2023-07-01  Instagram
# ...

# %%
df3.describe()
# Out:
#                      InteractionDate         Year
# count                           2920  2920.000000
# mean   2023-12-30 17:19:04.109588736  2023.498973
# min              2023-07-01 00:00:00  2023.000000
# 25%              2023-10-01 18:00:00  2023.000000
# 50%              2023-12-31 00:00:00  2023.000000
# 75%              2024-04-01 00:00:00  2024.000000
# max              2024-06-30 00:00:00  2024.000000
# std                              NaN     0.500085

# %%
# Frequency counts for categorical variables in Social Media Interactions
platform_counts = df3['Platform'].value_counts()
interaction_type_counts = df3['InteractionType'].value_counts()
sentiment_counts = df3['Sentiment'].value_counts()
month_counts = df3['Month'].value_counts()
year_counts = df3['Year'].value_counts()

print("Platform Counts:\n", platform_counts)
print("Interaction Type Counts:\n", interaction_type_counts)
print("Sentiment Counts:\n", sentiment_counts)
print("Month Counts:\n", month_counts)
print("Month Counts:\n", year_counts)
# Out:
# Platform Counts:
#  Platform
# Instagram    889
# Twitter      882
# Facebook     867
# Others       282
# Name: count, dtype: int64
# Interaction Type Counts:
#  InteractionType
# Comment    985
# Share      969
# Like       966
# Name: count, dtype: int64
# Sentiment Counts:
#  Sentiment
# Neutral          1140
# Positive          874
# Negative          841
# Very Negative      33
# Very Positive      32
# Name: count, dtype: int64
# Month Counts:
#  Month
# July         263
# May          258
# October      256
# December     254
# January      248
# April        247
# March        241
# August       232
# February     232
# June         231
# September    230
# November     228
# Name: count, dtype: int64
# Month Counts:
#  Year
# 2023    1463
# 2024    1457
# Name: count, dtype: int64

# %% [markdown]
# ## Charts

# %%
# Frequency counts for categorical variables in Social Media Interactions
platform_counts = df3['Platform'].value_counts()
interaction_type_counts = df3['InteractionType'].value_counts()
sentiment_counts = df3['Sentiment'].value_counts()
month_counts = df3['Month'].value_counts()
year_counts = df3['Year'].value_counts()

# Ensure month counts are sorted properly (if months are strings)
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']
month_counts = month_counts.reindex(month_order).fillna(0)  # Reindex to ensure proper order

# Set up the plots
plt.figure(figsize=(15, 10))

# Platform Counts
plt.subplot(3, 2, 1)
platform_counts.plot(kind='bar', color='lightblue')
plt.title('Platform Counts')
plt.xlabel('Platform')
plt.ylabel('Count')

# Interaction Type Counts
plt.subplot(3, 2, 3)
interaction_type_counts.plot(kind='bar', color='lightgreen')
plt.title('Interaction Type Counts')
plt.xlabel('Interaction Type')
plt.ylabel('Count')

# Sentiment Counts
plt.subplot(3, 2, 4)
sentiment_counts.plot(kind='bar', color='salmon')
plt.title('Sentiment Counts')
plt.xlabel('Sentiment')
plt.ylabel('Count')

# Month Counts
plt.subplot(3, 2, 5)
month_counts.plot(kind='bar', color='gold')
plt.title('Month Counts')
plt.xlabel('Month')
plt.ylabel('Count')

# Year Counts
plt.subplot(3, 2, 6)
year_counts.plot(kind='bar', color='lightcoral')
plt.title('Year Counts')
plt.xlabel('Year')
plt.ylabel('Count')

# Adjust layout
plt.tight_layout()
plt.show()
